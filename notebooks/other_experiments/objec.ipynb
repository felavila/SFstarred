# %%
from SFstarred.SpaceData import SpaceData
import matplotlib.pyplot as plt
from matplotlib.colors import SymLogNorm, LogNorm, Normalize, TwoSlopeNorm
import numpy as np
from copy import deepcopy
from SFstarred.utils import make_a_fits_list_csv
from astropy.io import fits

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
jeje = make_a_fits_list_csv("/home/felipe/work/Data_for_Starred/mast_data/WISEJ0259")

# %%
path_data = "/home/felipe/work/Data/mast_data/WFIJ2033/JWST/mastDownload/JWST/jw02046-o021_t020_miri_f560w/jw02046-o021_t020_miri_f560w_i2d.fits"

# %%
DataClass.lens_table[["Comp","sep_arcsec"]]
# Out:
#   Comp  sep_arcsec
# 0    C    0.826802
# 1    D    0.610382
# 2    G    0.084255
# 3    B    0.769089
# 4    A    0.751594

# %%
# DataClass.lens_table.columns

# %%
import astropy.units as u
from astropy.wcs.utils import proj_plane_pixel_scales

# wcs = your astropy.wcs.WCS object

pixscale_deg = proj_plane_pixel_scales(DataClass.cutout_2d.wcs) * u.deg
pixscale_arcsec = pixscale_deg.to(u.arcsec)

print(pixscale_arcsec)
# Out:
# [0.11092424 0.11092424] arcsec

# %%
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN' 'DEC--TAN'
# CUNIT : 'deg' 'deg'
# CRVAL : 44.92664590532245 -16.58977610112258
# CRPIX : -167.18438517404218 34.122807972635655
# PC1_1 PC1_2  : 0.2535893623178615 -0.9673119638044494
# PC2_1 PC2_2  : -0.9673119638044494 -0.2535893623178615
# CDELT : 3.08122883598093e-05 3.08122883598093e-05
# NAXIS : 40  40

# %%
for path_data in jeje.path.values:
	print(path_data)
	DataClass = SpaceData(path_data)
	num_pix = 100
	percentiles=(1,99)
	if DataClass.TELESCOP=="JWST":
		num_pix= 40
		percentiles =(1,99) 
	DataClass.cut_light(plot=True,num_pix=num_pix,percentiles=percentiles,add_colorbar=True,norm=None,cmap="inferno")
	pixscale_deg = proj_plane_pixel_scales(DataClass.cutout_2d.wcs.celestial) * u.deg
	pixscale_arcsec = pixscale_deg.to(u.arcsec)
	print(pixscale_arcsec)
	print("####################")
	#break
# Out:
# /home/felipe/work/Data_for_Starred/mast_data/WISEJ0259/HST/mastDownload/HST/hst_skycell-p0891x15y17_wfc3_ir_f160w_all/hst_skycell-p0891x15y17_wfc3_ir_f160w_all_drz.fits
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# values use for fwhm = 6 and threshold = 0.12594034083653305
# Centroid refinement failed: box_size must have an odd value for both axes
# [0.04 0.04] arcsec
# ####################
# /home/felipe/work/Data_for_Starred/mast_data/WISEJ0259/HST/mastDownload/HST/hst_skycell-p0891x15y17_wfc3_uvis_f814w_all/hst_skycell-p0891x15y17_wfc3_uvis_f814w_all_drc.fits
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]
# values use for fwhm = 5 and threshold = 0.05671235370695305
# Centroid refinement failed: box_size must have an odd value for both axes
# [0.04 0.04] arcsec
# ####################
# ...

# %%
DataClass
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# DATE    = '2024-11-19'         / date this file was written (yyyy-mm-dd)
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# NEXTEND =                    4 / Number of standard extensions
# FILENAME= 'hst_skycell-p0891x15y17_wfc3_ir_f160w_coarse-all_drz.fits' / name of
# FILETYPE= 'SCI      '          / type of data found in data file
#
# TELESCOP= 'HST'                / telescope used to acquire data
# INSTRUME= 'WFC3  '             / identifier for instrument used to acquire data
# EQUINOX =               2000.0 / equinox of celestial coord. system
#
#               / DATA DESCRIPTION KEYWORDS
#
# ...
