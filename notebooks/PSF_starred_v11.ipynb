# %%
from SFstarred.DataStarred import DataStarred
import matplotlib.pyplot as plt
from matplotlib.colors import SymLogNorm, LogNorm, Normalize, TwoSlopeNorm

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np

# %%
path_data = "HST_IMAGES_0214_2105/WG0214-2105_F160W_drz_sci.fits"
path_weight = "HST_IMAGES_0214_2105/WG0214-2105_F160W_drz_wht.fits"
# Data setup for starred
#remove_star: 5 (light contamination from other source), 8 (it is one of the QSO images); 9 (large residuals) 
data_F160W=DataStarred(path_data,path_weight)
# Out:
# WARNING: Input data contains invalid values (NaNs or infs), which were automatically clipped. [astropy.stats.sigma_clipping]

# %%
# data_F160W.get_gaia_stars()

# %%
data_F160W.detect_stars(make_plots=True,use_gaia=False)
# Out:
# The search for stars will be with detec_fwhm = 5.000 and threshold = 0.543
# Detected 20 stars outside the object region.
# <DeprecatedColumnQTable length=20>
#   id      x_centroid     ...         mag             daofind_mag
# int64      float64       ...       float64             float64
# ----- ------------------ ... ------------------- -------------------
#    28 1703.3717210665402 ...  -7.918651036309243  -6.367098598605152
#    49 1067.9908662164733 ...  -5.921625146902073 -3.4421520390474254
#    21 1102.7917798663395 ...  -5.344918768423997  -3.003812871679212
#    43 1068.8492472702835 ...  -5.268026449722298 -2.9857395682212386
#    24 1835.0603472221762 ...  -5.122500963434705  -2.640219598557831
#    35  1143.929190631902 ...  -4.844329349819469 -3.3224118563517377
#    48 1023.7577687967923 ...  -4.642041635161402  -2.519267449443538
#    17 1385.1659101017308 ... -4.5022914003853725  -2.145441674911262
#    40  799.3457732254896 ...  -4.496565660118063  -2.423717599455908
#     5 1468.8404970923787 ...  -4.489784415395593  -1.594803065430355
#    38 1284.8725171918413 ...  -4.451301348734127 -2.8718867784733604
#    16  890.9045130482449 ...  -4.412252450658142 -2.0009411518937306
#    12  651.4434234936356 ...  -4.405851881626639  -2.330290880605082
#    32  887.4426563484591 ...  -4.291355771543999 -2.6675059952509157
#    47 1511.3896004404723 ...  -4.259133900324618  -2.457115978092321
#    18 316.30499569650766 ...  -4.252747730359739 -2.7293464033195374
#    51 1369.7602014505028 ...   -4.23260708451013 -1.7234455696587037
#     9  1718.630996326016 ... -4.1638130550426276 -1.8378443753085598
#    23 1158.3472985906353 ...  -4.073727696053023  -1.828060185911156
#    53   838.551459949358 ...  -4.054500814546008 -1.6294758015842181

# %%
data_F160W.plot_stars()
# Out:
# [ 33.55612689 -21.08880546]
# [ 33.57125978 -21.07524514]
# [ 33.5704312  -21.09247703]
# [ 33.57123942 -21.07992311]
# [ 33.55299024 -21.0903602 ]
# [ 33.56945133 -21.08306585]
# [ 33.57231321 -21.07567313]
# [ 33.56370552 -21.09518501]
# [ 33.57765795 -21.08052259]
# [ 33.56171211 -21.1040076 ]
# [ 33.56609458 -21.08196345]
# [ 33.57547813 -21.09670683]
# [ 33.5811821  -21.10046835]
# [ 33.57555997 -21.08348826]
# [ 33.56070002 -21.0771996 ]
# [ 33.58916405 -21.09465428]
# [ 33.56407315 -21.07260731]
# [ 33.55576227 -21.10252268]
# [ 33.56910797 -21.09067763]
# [ 33.5767237  -21.07095179]

# %%
data_raw = data_F160W.data_raw
wcs = data_F160W.wcs

# %%
plt.figure(figsize=(20, 20))
plt.imshow(data_raw, cmap='Greys', norm=LogNorm(1e-6))
